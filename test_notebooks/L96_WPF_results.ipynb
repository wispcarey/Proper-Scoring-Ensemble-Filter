# %%
cd /resnick/groups/astuart/bhchen/Learn_DA_selfuse
# Out:
# /resnick/groups/astuart/bhchen/Learn_DA_selfuse
# /home/bhchen/miniconda3/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
experiment_configs = [
    {
        "path": "2026-01-07_16-42lorenz96_1.0_10_60_8192_es_joint_EtE-LRes",
        "tags": ["EtE", "ES"]
    },
    {
        "path": "2026-01-14_01-24lorenz96_1.0_10_60_8192_es_joint_CorrTerms",
        "tags": ["CorrTerms", "ES"]
    },
    {
        "path": "2026-01-07_17-39lorenz96_1.0_10_60_8192_nl2_joint_CorrTerms",
        "tags": ["CorrTerms", "NL2"]
    },
    {
        "path": "2026-02-04_17-05lorenz96_1.0_10_60_8192_nll_joint_CorrTerms",
        "tags": ["CorrTerms", "NLL"]
    },
    {
        "path": "2026-02-04_17-05lorenz96_1.0_10_60_8192_nll_joint_EtE-LRes",
        "tags": ["EtE", "NLL"]
    },
    {
        "path": "2026-02-04_17-05lorenz96_1.0_10_60_8192_wpf_ammd_joint_CorrTerms",
        "tags": ["CorrTerms", "MMD"]
    },
    {
        "path": "2026-02-04_17-05lorenz96_1.0_10_60_8192_wpf_ammd_joint_EtE-LRes",
        "tags": ["EtE", "MMD"]
    },
    {
        "path": "2026-02-04_17-05lorenz96_1.0_10_60_8192_wpf_ed_joint_CorrTerms",
        "tags": ["CorrTerms", "ED"]
    },
    {
        "path": "2026-02-04_17-05lorenz96_1.0_10_60_8192_wpf_ed_joint_EtE-LRes",
        "tags": ["EtE", "ED"]
    },
    {
        "path": "2026-02-04_17-05lorenz96_1.0_10_60_8192_wpf_st_ammd_joint_CorrTerms",
        "tags": ["CorrTerms", "SG", "MMD"]
    },
    {
        "path": "2026-02-04_17-05lorenz96_1.0_10_60_8192_wpf_st_ammd_joint_EtE-LRes",
        "tags": ["EtE", "SG", "MMD"]
    },
    {
        "path": "2026-02-04_17-05lorenz96_1.0_10_60_8192_wpf_st_ed_joint_CorrTerms",
        "tags": ["CorrTerms", "SG", "ED"]
    },
    {
        "path": "2026-02-04_17-05lorenz96_1.0_10_60_8192_wpf_st_ed_joint_EtE-LRes",
        "tags": ["EtE", "SG", "ED"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_nnll_joint_CorrTerms",
        "tags": ["CorrTerms", "NNLL"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_nnll_joint_EtE-LRes",
        "tags": ["EtE", "NNLL"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nll_joint_CorrTerms",
        "tags": ["CorrTerms", "ahead_NLL"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nll_joint_EtE-LRes",
        "tags": ["EtE", "ahead_NLL"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nll_wpf_ammd_joint_CorrTerms",
        "tags": ["CorrTerms", "ahead_NLL", "MMD"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nll_wpf_ammd_joint_EtE-LRes",
        "tags": ["EtE", "ahead_NLL", "MMD"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nll_wpf_ed_joint_CorrTerms",
        "tags": ["CorrTerms", "ahead_NLL", "ED"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nll_wpf_ed_joint_EtE-LRes",
        "tags": ["EtE", "ahead_NLL", "ED"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nll_wpf_st_ammd_joint_CorrTerms",
        "tags": ["CorrTerms", "ahead_NLL", "MMD", "SG"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nll_wpf_st_ammd_joint_EtE-LRes",
        "tags": ["EtE", "ahead_NLL", "MMD", "SG"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nll_wpf_st_ed_joint_CorrTerms",
        "tags": ["CorrTerms", "ahead_NLL", "ED", "SG"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nll_wpf_st_ed_joint_EtE-LRes",
        "tags": ["EtE", "ahead_NLL", "ED", "SG"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nnll_joint_CorrTerms",
        "tags": ["CorrTerms", "ahead_NNLL"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nnll_joint_EtE-LRes",
        "tags": ["EtE", "ahead_NNLL"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nnll_wpf_ammd_joint_EtE-LRes",
        "tags": ["EtE", "ahead_NNLL", "MMD"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nnll_wpf_ed_joint_CorrTerms",
        "tags": ["CorrTerms", "ahead_NNLL", "ED"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nnll_wpf_ed_joint_EtE-LRes",
        "tags": ["EtE", "ahead_NNLL", "ED"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nnll_wpf_st_ammd_joint_EtE-LRes",
        "tags": ["EtE", "ahead_NNLL", "MMD", "SG"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nnll_wpf_st_ed_joint_CorrTerms",
        "tags": ["CorrTerms", "ahead_NNLL", "ED", "SG"]
    },
    {
        "path": "2026-02-04_17-06lorenz96_1.0_10_60_8192_pre_nnll_wpf_st_ed_joint_EtE-LRes",
        "tags": ["EtE", "ahead_NNLL", "ED", "SG"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nll_wpf_ammd_joint_CorrTerms",
        "tags": ["CorrTerms", "NLL", "MMD"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nll_wpf_ammd_joint_EtE-LRes",
        "tags": ["EtE", "NLL", "MMD"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nll_wpf_ed_joint_CorrTerms",
        "tags": ["CorrTerms", "NLL", "ED"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nll_wpf_ed_joint_EtE-LRes",
        "tags": ["EtE", "NLL", "ED"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nll_wpf_st_ammd_joint_CorrTerms",
        "tags": ["CorrTerms", "NLL", "MMD", "SG"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nll_wpf_st_ammd_joint_EtE-LRes",
        "tags": ["EtE", "NLL", "MMD", "SG"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nll_wpf_st_ed_joint_CorrTerms",
        "tags": ["CorrTerms", "NLL", "ED", "SG"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nll_wpf_st_ed_joint_EtE-LRes",
        "tags": ["EtE", "NLL", "ED", "SG"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nnll_wpf_ammd_joint_CorrTerms",
        "tags": ["CorrTerms", "NNLL", "MMD"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nnll_wpf_ammd_joint_EtE-LRes",
        "tags": ["EtE", "NNLL", "MMD"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nnll_wpf_ed_joint_CorrTerms",
        "tags": ["CorrTerms", "NNLL", "ED"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nnll_wpf_ed_joint_EtE-LRes",
        "tags": ["EtE", "NNLL", "ED"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nnll_wpf_st_ammd_joint_CorrTerms",
        "tags": ["CorrTerms", "NNLL", "MMD", "SG"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nnll_wpf_st_ammd_joint_EtE-LRes",
        "tags": ["EtE", "NNLL", "MMD", "SG"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nnll_wpf_st_ed_joint_CorrTerms",
        "tags": ["CorrTerms", "NNLL", "ED", "SG"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_nnll_wpf_st_ed_joint_EtE-LRes",
        "tags": ["EtE", "NNLL", "ED", "SG"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_pre_nnll_wpf_ammd_joint_CorrTerms",
        "tags": ["CorrTerms", "ahead_NNLL", "MMD"]
    },
    {
        "path": "2026-02-04_17-07lorenz96_1.0_10_60_8192_pre_nnll_wpf_st_ammd_joint_CorrTerms",
        "tags": ["CorrTerms", "ahead_NNLL", "MMD", "SG"]
    }
]

# %%
import torch
import os
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from IPython.display import display, clear_output

# =================== Configuration & Style ===================

MAIN_LINE_WIDTH = 2.0
X_LIM = (-0.5, 500) 
GRID_LS = "--"
GRID_ALPHA = 0.6
OUT_DIR = os.path.join("save", "figures")
os.makedirs(OUT_DIR, exist_ok=True)

metrics_config = [
    {"key": 'mean_rrmse', "ylabel": "RRMSE", "fname": "rrmse", "ylim": (0, 1)},
    {"key": 'mean_rcrps', "ylabel": "RCRPS", "fname": "rcrps", "ylim": (0, 1)},
]

def get_method_style(tags):
    """
    Determine color and linestyle based on method tags.
    """
    # 1. Determine Line Style based on CorrTerms and SG combinations
    has_corr = "CorrTerms" in tags
    has_sg = "SG" in tags
    
    if not has_corr and not has_sg:
        ls = "-"           # Solid: Base
    elif has_corr and not has_sg:
        ls = "--"          # Dashed: CorrTerms only
    elif not has_corr and has_sg:
        ls = ":"           # Dotted: SG only
    else: # has_corr and has_sg
        ls = "-."          # Dash-dot: Both
    
    # 2. Determine Color based on Loss + Regularizer combo
    if "ahead_NLL" in tags:
        if "ED" in tags:
            color = "tab:brown"
        elif "MMD" in tags:
            color = "tab:pink"
        else:
            color = "tab:purple"
            
    elif "NLL" in tags:
        if "ED" in tags:
            color = "tab:red"
        elif "MMD" in tags:
            color = "tab:green"
        else:
            color = "tab:orange"
            
    elif "NL2" in tags:
        color = "tab:cyan"
        
    elif "ES" in tags:
        color = "tab:blue"
    else:
        color = "black"

    return {"color": color, "linestyle": ls}

# =================== UI Components ===================

all_tags = sorted(list(set(t for c in experiment_configs for t in c["tags"])))

tag_checks = [
    widgets.Checkbox(
        value=True, 
        description=tag, 
        style={'description_width': 'initial'}, 
        layout=widgets.Layout(width='auto', margin='0px 15px 0px 0px') 
    ) for tag in all_tags
]

save_check = widgets.Checkbox(
    value=False, 
    description="Save Figures (PDF)", 
    style={'description_width': 'initial'}
)
side_legend_check = widgets.Checkbox(
    value=True, 
    description="Show Side Legend", 
    style={'description_width': 'initial'}
)
btn_plot = widgets.Button(
    description="Generate Plots", 
    button_style='primary', 
    icon='area-chart'
)
output = widgets.Output()

def run_plotting(_):
    with output:
        clear_output(wait=True)
        selected_tags = set([chk.description for chk in tag_checks if chk.value])
        
        if not selected_tags:
            print("Please select at least one tag.")
            return

        active_configs = [
            c for c in experiment_configs 
            if set(c["tags"]).issubset(selected_tags)
        ]
        
        handles, labels = [], []

        for metric in metrics_config:
            fig, ax = plt.subplots(figsize=(12, 6))
            lines_plotted_in_axis = False 
            
            for config in active_configs:
                # Construct and verify file path
                folder_path = os.path.join('save', config["path"])
                file_path = os.path.join(folder_path, 'training_records.pt')
                
                if not os.path.exists(folder_path):
                    print(f"Warning: Folder missing -> {folder_path}")
                    continue
                
                if not os.path.exists(file_path):
                    print(f"Warning: File missing -> {file_path}")
                    continue

                # Load data and validate metric existence
                data = torch.load(file_path, weights_only=True, map_location="cpu")
                curve = np.array(data.get(metric['key'], []))
                epochs = np.array(data.get('test_epochs', []))
                
                if len(curve) > 0:
                    name = "+".join(config["tags"])
                    style = get_method_style(config["tags"])
                    ln, = ax.plot(epochs, curve, label=name, lw=MAIN_LINE_WIDTH, **style)
                    lines_plotted_in_axis = True
                    
                    if metric == metrics_config[0]:
                        handles.append(ln)
                        labels.append(name)

            # Finalize plot formatting
            ax.set_title(f"Lorenz96 - {metric['ylabel']}", fontsize=16)
            ax.set_ylabel(metric['ylabel'], fontsize=14)
            ax.set_xlabel('Epoch', fontsize=14)
            ax.grid(True, ls=GRID_LS, alpha=GRID_ALPHA)
            ax.set_xlim(*X_LIM)
            if metric['ylim']: ax.set_ylim(*metric['ylim'])
            
            # Only trigger legend if artists exist to avoid UserWarning
            if side_legend_check.value and lines_plotted_in_axis:
                ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), frameon=False)

            if save_check.value:
                save_path = os.path.join(OUT_DIR, f"Lorenz96_{metric['fname']}.pdf")
                plt.savefig(save_path, format="pdf", bbox_inches="tight")
            
            plt.show()

        # Handle standalone legend generation
        if handles:
            n_items = len(handles)
            ncol = min(5, n_items)
            nrow = int(np.ceil(n_items / ncol))
            
            fig_leg, ax_leg = plt.subplots(figsize=(10, 0.6 * nrow))
            ax_leg.axis('off')
            ax_leg.legend(handles, labels, loc='center', ncol=ncol, frameon=False)
            
            if save_check.value:
                plt.savefig(os.path.join(OUT_DIR, "legend_standalone.pdf"), bbox_inches="tight")
            plt.show()

# =================== Interactive UI Layout ===================

# Group tags into rows, with a maximum of 5 items per row
tag_rows = [widgets.HBox(tag_checks[i:i + 5]) for i in range(0, len(tag_checks), 5)]

# Assemble the Tags Section container
tags_header = widgets.HTML("<h4>Method Tags (Select to Filter)</h4>")
tags_container = widgets.VBox([tags_header] + tag_rows)

# Assemble the Control Section container
controls_header = widgets.HTML("<h4>Plotting Controls</h4>")
controls_hbox = widgets.HBox([save_check, side_legend_check, btn_plot])
controls_container = widgets.VBox([
    widgets.HTML("<hr>"), 
    controls_header, 
    controls_hbox
])

# Final Display Structure
ui = widgets.VBox([
    tags_container, 
    controls_container, 
    widgets.HTML("<br>"), 
    output
])

# Render the UI
display(ui)

# Bind the click event
btn_plot.on_click(run_plotting)
